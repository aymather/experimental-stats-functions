# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
"""

Log Line

"""

i = np.linspace(1, 100)
ii = [math.log(i) for i in x]
plt.scatter(i, ii, color='red')
plt.plot(i, ii)
plt.show()

# %%
b = np.linspace(1, 100)
bb = [math.pow(i, 2) for i in b]
plt.scatter(b, bb)
plt.plot(b, bb, color='red')
plt.show()

# %%
g = np.linspace(1, 500, 250)
gg = [math.cos(i) for i in g]
plt.scatter(g, gg)
plt.plot(g, gg, color='red')
plt.show()
